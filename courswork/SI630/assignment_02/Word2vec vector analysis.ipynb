# %% [markdown]
# # SI630 Homework 2: Word2vec Vector Analysis
#
# *Important Note:* Start this notebook only after you've gotten your word2vec model up and running!
#
# Many NLP packages support working with word embeddings. In this notebook you can work through the various problems assigned in Task 3. We've provided the basic functionality for loading word vectors using [Gensim](https://radimrehurek.com/gensim/models/keyedvectors.html), a good library for learning and using word vectors, and for working with the vectors.
#
# One of the fun parts of word vectors is getting a sense of what they learned. Feel free to explore the vectors here!

# %%
from gensim.models import KeyedVectors
from gensim.test.utils import datapath

# %%
word_vectors = KeyedVectors.load_word2vec_format('Word2Vec_Model', binary=False)

# %%
word_vectors['the']
# Out:
# array([ 0.25596148,  0.27567005,  0.24742034,  0.31901658, -0.32142407,
#        -0.2558528 , -0.24441342, -0.32059112,  0.38258576,  0.3101376 ,
#         0.27823207,  0.33833006,  0.31902236, -0.28096232,  0.3110848 ,
#         0.33002234,  0.14471766,  0.33966514, -0.29717088,  0.22672425,
#         0.3324133 , -0.2197797 , -0.29371443,  0.2642938 , -0.26269996,
#        -0.23402067,  0.32403487,  0.33519778,  0.29100204, -0.26296166,
#        -0.28934327, -0.3110694 , -0.25694886, -0.2846095 , -0.30052316,
#        -0.34136784, -0.31313464, -0.24052876,  0.2446698 , -0.2857243 ,
#         0.20365894,  0.24637224,  0.24282731, -0.18036401,  0.29452068,
#        -0.32079816,  0.20149298,  0.2767359 ,  0.28902394, -0.31774268],
#       dtype=float32)

# %%
word_vectors.similar_by_word("books")
# Out:
# [('songs', 0.9999173283576965),
#  ('paintings', 0.9998435378074646),
#  ('encouraged', 0.9998093843460083),
#  ('close', 0.9998033046722412),
#  ('critical', 0.9997953772544861),
#  ('supported', 0.9997947216033936),
#  ('musicians', 0.9997925162315369),
#  ('gabirol', 0.9997822046279907),
#  ('stories', 0.9997695088386536),
#  ('inspired', 0.999757707118988)]

# %%
target_words = [
    'doctor',
    'technical',
    'motivated',
    'ethical',
    'earnings',
    'sports',
    'dancer',
    'artistic',
    'lazy'
]

for t in target_words:
    print(f"Target word: {t}")
    print(word_vectors.similar_by_word(t))
    print("")
# Out:
# Target word: doctor
# [('founding', 0.999644935131073), ('founder', 0.9995342493057251), ('chair', 0.9995135068893433), ('mathematics', 0.9993555545806885), ('foreign', 0.9993261098861694), ('schools', 0.9992579817771912), ('medicine', 0.9992494583129883), ('associate', 0.9992328882217407), ('fellow', 0.9991998076438904), ('taught', 0.9991545081138611)]
#
# Target word: technical
# [('industrial', 0.9999467134475708), ('environmental', 0.9999301433563232), ('finance', 0.9998579621315002), ('obtained', 0.9998190402984619), ('applied', 0.9998027682304382), ('biology', 0.9997803568840027), ('advisory', 0.9997748136520386), ('sociology', 0.9997384548187256), ('pontifical', 0.9997186660766602), ('directors', 0.9997177124023438)]
#
# Target word: motivated
# [('documented', 0.9999889731407166), ('interesting', 0.9999594688415527), ('looked', 0.9999566674232483), ('bit', 0.9999517798423767), ('perhaps', 0.9999509453773499), ('truly', 0.9999485611915588), ('incorporate', 0.9999483823776245), ('funds', 0.9999455809593201), ('permission', 0.9999446272850037), ('neither', 0.9999443292617798)]
#
# Target word: ethical
# [('examination', 0.9999794363975525), ('steering', 0.9999590516090393), ('erlangen', 0.9999575614929199), ('classmate', 0.9999538660049438), ('code', 0.9999518990516663), ('judiciary', 0.9999498724937439), ('navigation', 0.9999492168426514), ('dickinson', 0.9999489188194275), ('contingent', 0.999944806098938), ('duchess', 0.9999445080757141)]
#
# Target word: earnings
# [('wicket', 0.9999545812606812), ('remaining', 0.9999386668205261), ('apparatus', 0.9999382495880127), ('span', 0.9999359250068665), ('sakata', 0.9999300837516785), ('leumi', 0.9999224543571472), ('loot', 0.9999212026596069), ('groucho', 0.9999195337295532), ('leap', 0.9999179244041443), ('menorca', 0.9999175071716309)]
#
# Target word: sports
# [('chinese', 0.9999141693115234), ('african', 0.9998711347579956), ('middle', 0.9998599290847778), ('vitality', 0.9998408555984497), ('banking', 0.9998188614845276), ('mortuary', 0.9998090267181396), ('defence', 0.9998031258583069), ('kampong', 0.9997996687889099), ('cosmology', 0.9997965097427368), ('bodmin', 0.9997894167900085)]
#
# Target word: dancer
# [('pilot', 0.9999697208404541), ('apprentice', 0.9999596476554871), ('columnist', 0.9999485015869141), ('witness', 0.9999461770057678), ('auxiliary', 0.9999446868896484), ('novelist', 0.9999430179595947), ('specialist', 0.9999430179595947), ('cleric', 0.9999342560768127), ('investigator', 0.9999309182167053), ('schoolmaster', 0.9999272227287292)]
#
# Target word: artistic
# [('intelligence', 0.9998781681060791), ('system', 0.9998722076416016), ('spatial', 0.9998547434806824), ('segarra', 0.9998418688774109), ('cantonment', 0.9998387098312378), ('councilors', 0.9998329877853394), ('intellectual', 0.9998196959495544), ('project', 0.999800443649292), ('interests', 0.9997758269309998), ('tripati', 0.9997707009315491)]
#
# Target word: lazy
# [('gottschalk', 0.9999501705169678), ('nga', 0.9999423027038574), ('ain', 0.9999291300773621), ('renomination', 0.9999269247055054), ('upright', 0.9999257326126099), ('sad', 0.9999235272407532), ('sheer', 0.999919593334198), ('interlude', 0.99991774559021), ('liquor', 0.9999108910560608), ('farnham', 0.9999105930328369)]

# %% [markdown]
# For most target words above, the most similar terms appear to be semantically similar. For example, doctor returned terms such as chair, schools, medicine, and taught. The target word technical returned industrial, finance, applied, sociology, and more.
#
# Some exceptions include sports, where the top terms were chinese, african, middle, vitality, and banking. These seem peripherally related at best (e.g. chinese gymnastics, african football, etc.), and completely off (e.g. banking, vitality)

# %%
def get_analogy(a, b, c):
    return word_vectors.most_similar(positive=[b, c], negative=[a])[0][0]

# %%
get_analogy('immigration', 'policy', 'legal')
# Out:
# 'social'

# %%
get_analogy('safety', 'fund', 'republican')
# Out:
# 'liberal'

# %%
get_analogy('male', 'female', 'doctor')
# Out:
# 'editor'

# %%
get_analogy('college', 'university', 'technical')
# Out:
# 'state'

# %%
get_analogy('sports', 'studying', 'physical')
# Out:
# 'dictation'

# %%
get_analogy('baseball', 'boxing', 'relaxing')
# Out:
# 'kamikaze'

# %% [markdown]
# Above are the six examples of word associations similar to the queen - woman = king - man example. Some of these appear to be pretty sound, others are puzzling. For example, legal - immigration = policy - *social* feels pretty accurate. Another accurate comparison might be physical - sports = studying - *dictation*. One example that's a little puzzling, but not inaccurate if you think about it, is relaxing - baseball = boxing - *kamikaze*. Kamikaze refers to a "kamikaze attack or pilot" from WW2 where the Japanese would load an aircraft with explosives and deliberately crash into an enemy target, killing the pilot. This form of suicide feels extreme, but not exactly off the mark when associated with boxing which requires exteme physical demands.

# %% [markdown]
# ## Debiased Model Results

# %%
debiased_word_vectors = KeyedVectors.load_word2vec_format('Debiased_Word2Vec_Model', binary=False)

# %%
import csv

with open('word_pair_similarity_predictions.csv', newline='') as f:
    reader = csv.reader(f)
    incomplete = list(reader)
f.close()
    
incomplete[0]
# Out:
# ['word1', 'word2', 'sim']

# %%
complete = []
for pairs in incomplete[1:]:
    complete.append([pairs[0], pairs[1], debiased_word_vectors.similarity(pairs[0], pairs[1])])

complete
# Out:
# [['old', 'new', 0.8739896],
#  ['smart', 'intelligent', 0.9959426],
#  ['hard', 'difficult', 0.961006],
#  ['happy', 'cheerful', 0.9766615],
#  ['hard', 'easy', 0.98150903],
#  ['fast', 'rapid', 0.989959],
#  ['happy', 'glad', 0.9993435],
#  ['short', 'long', 0.9945617],
#  ['stupid', 'dumb', 0.9916815],
#  ['weird', 'strange', 0.9998329],
#  ['wide', 'narrow', 0.8304432],
#  ['bad', 'awful', 0.9980965],
#  ['easy', 'difficult', 0.99586153],
#  ['bad', 'terrible', 0.9981045],
#  ['hard', 'simple', 0.9806286],
#  ['smart', 'dumb', 0.9955488],
#  ['insane', 'crazy', 0.9991684],
#  ['happy', 'mad', 0.9518202],
#  ['large', 'huge', 0.9728311],
#  ['hard', 'tough', 0.9854515],
#  ['new', 'fresh', 0.9426073],
#  ['sharp', 'dull', 0.9896795],
#  ['quick', 'rapid', 0.9883007],
#  ['dumb', 'foolish', 0.9875476],
#  ['wonderful', 'terrific', 0.9989617],
#  ['strange', 'odd', 0.99894124],
#  ['happy', 'angry', 0.99707395],
#  ['narrow', 'broad', 0.87837625],
#  ['simple', 'easy', 0.99912465],
#  ['old', 'fresh', 0.9688447],
#  ['apparent', 'obvious', 0.99819773],
#  ['inexpensive', 'cheap', 0.99454033],
#  ['nice', 'generous', 0.9746314],
#  ['weird', 'normal', 0.9930629],
#  ['weird', 'odd', 0.99838394],
#  ['bad', 'immoral', 0.99662274],
#  ['sad', 'funny', 0.9967997],
#  ['wonderful', 'great', 0.9704131],
#  ['guilty', 'ashamed', 0.99789643],
#  ['beautiful', 'wonderful', 0.9977822],
#  ['confident', 'sure', 0.99852777],
#  ['dumb', 'dense', 0.9967032],
#  ['large', 'big', 0.95212257],
#  ['nice', 'cruel', 0.9826164],
#  ['impatient', 'anxious', 0.99901915],
#  ['big', 'broad', 0.9975402],
#  ['strong', 'proud', 0.99704254],
#  ['unnecessary', 'necessary', 0.9981198],
#  ['restless', 'young', 0.97910345],
#  ['dumb', 'intelligent', 0.9980779],
#  ['bad', 'great', 0.97045547],
#  ['difficult', 'simple', 0.99582016],
#  ['necessary', 'important', 0.9862641],
#  ['bad', 'terrific', 0.9987168],
#  ['mad', 'glad', 0.9547406],
#  ['honest', 'guilty', 0.99935955],
#  ['easy', 'tough', 0.9989354],
#  ['easy', 'flexible', 0.99843776],
#  ['certain', 'sure', 0.9985864],
#  ['essential', 'necessary', 0.9978044],
#  ['different', 'normal', 0.9986435],
#  ['sly', 'clever', 0.97962266],
#  ['crucial', 'important', 0.9134422],
#  ['harsh', 'cruel', 0.9950327],
#  ['childish', 'foolish', 0.96750945],
#  ['scarce', 'rare', 0.9952737],
#  ['friendly', 'generous', 0.6705378],
#  ['fragile', 'frigid', 0.9755751],
#  ['long', 'narrow', 0.8602122],
#  ['big', 'heavy', 0.9992761],
#  ['rough', 'frigid', 0.9906737],
#  ['bizarre', 'strange', 0.99976283],
#  ['illegal', 'immoral', 0.99137664],
#  ['bad', 'guilty', 0.9979437],
#  ['modern', 'ancient', 0.9920222],
#  ['new', 'ancient', 0.9638515],
#  ['dull', 'funny', 0.9880051],
#  ['happy', 'young', 0.9931917],
#  ['easy', 'big', 0.9920492],
#  ['great', 'awful', 0.9566182],
#  ['tiny', 'huge', 0.99948937],
#  ['polite', 'proper', 0.98453796],
#  ['modest', 'ashamed', 0.9964128],
#  ['exotic', 'rare', 0.99928635],
#  ['dumb', 'clever', 0.9991213],
#  ['delightful', 'wonderful', 0.99940723],
#  ['noticeable', 'obvious', 0.9977504],
#  ['afraid', 'anxious', 0.9893684],
#  ['formal', 'proper', 0.99838346],
#  ['dreary', 'dull', 0.961384],
#  ['delightful', 'cheerful', 0.9885874],
#  ['unhappy', 'mad', 0.9682065],
#  ['sad', 'terrible', 0.99958616],
#  ['sick', 'crazy', 0.999589],
#  ['violent', 'angry', 0.9970946],
#  ['laden', 'heavy', 0.9997187],
#  ['dirty', 'cheap', 0.9943954],
#  ['elastic', 'flexible', 0.9967677],
#  ['hard', 'dense', 0.9837403],
#  ['recent', 'new', 0.95209587],
#  ['bold', 'proud', 0.9913758],
#  ['sly', 'strange', 0.9876477],
#  ['strange', 'sly', 0.9876477],
#  ['dumb', 'rare', 0.9996219],
#  ['sly', 'tough', 0.98629713],
#  ['terrific', 'mad', 0.97576463],
#  ['modest', 'flexible', 0.9992589],
#  ['fresh', 'wide', 0.99633753],
#  ['huge', 'dumb', 0.99790967],
#  ['large', 'flexible', 0.97754323],
#  ['dirty', 'narrow', 0.9069314],
#  ['wife', 'husband', 0.99824506],
#  ['book', 'text', 0.9880093],
#  ['groom', 'bride', 0.9985516],
#  ['night', 'day', 0.99776304],
#  ['south', 'north', 0.9988597],
#  ['plane', 'airport', 0.9992317],
#  ['uncle', 'aunt', 0.9956765],
#  ['horse', 'mare', 0.96890986],
#  ['bottom', 'top', 0.98455614],
#  ['friend', 'buddy', 0.92201936],
#  ['student', 'pupil', 0.99263006],
#  ['world', 'globe', 0.92483836],
#  ['leg', 'arm', 0.9494735],
#  ['plane', 'jet', 0.99834025],
#  ['woman', 'man', 0.9905357],
#  ['horse', 'colt', 0.9515288],
#  ['actress', 'actor', 0.99939096],
#  ['teacher', 'instructor', 0.9850072],
#  ['movie', 'film', 0.98683834],
#  ['bird', 'hawk', 0.99619085],
#  ['word', 'dictionary', 0.99928033],
#  ['money', 'salary', 0.91794693],
#  ['dog', 'cat', 0.9381589],
#  ['area', 'region', 0.9958893],
#  ['navy', 'army', 0.9964538],
#  ['book', 'literature', 0.9963832],
#  ['clothes', 'closet', 0.9966882],
#  ['sunset', 'sunrise', 0.993595],
#  ['child', 'adult', 0.986385],
#  ['cow', 'cattle', 0.9948648],
#  ['book', 'story', 0.9976562],
#  ['winter', 'summer', 0.9909436],
#  ['taxi', 'cab', 0.9995952],
#  ['tree', 'maple', 0.7838366],
#  ['bed', 'bedroom', 0.9996599],
#  ['roof', 'ceiling', 0.9992728],
#  ['disease', 'infection', 0.9991465],
#  ['arm', 'shoulder', 0.99078417],
#  ['sheep', 'lamb', 0.99932194],
#  ['lady', 'gentleman', 0.99849665],
#  ['boat', 'anchor', 0.9995445],
#  ['priest', 'monk', 0.9972812],
#  ['toe', 'finger', 0.9995536],
#  ['river', 'stream', 0.99797356],
#  ['anger', 'fury', 0.96132934],
#  ['date', 'calendar', 0.95749354],
#  ['sea', 'ocean', 0.9984711],
#  ['second', 'minute', 0.939509],
#  ['hand', 'thumb', 0.9725877],
#  ['wood', 'log', 0.99905175],
#  ['mud', 'dirt', 0.9926786],
#  ['hallway', 'corridor', 0.9927777],
#  ['way', 'manner', 0.9997255],
#  ['mouse', 'cat', 0.97017205],
#  ['cop', 'sheriff', 0.9920353],
#  ['death', 'burial', 0.9903605],
#  ['music', 'melody', 0.93153787],
#  ['beer', 'alcohol', 0.9986863],
#  ['mouth', 'lip', 0.989133],
#  ['storm', 'hurricane', 0.99417996],
#  ['tax', 'income', 0.99715054],
#  ['flower', 'violet', 0.9983573],
#  ['paper', 'cardboard', 0.9854256],
#  ['floor', 'ceiling', 0.9957254],
#  ['beach', 'seashore', 0.97796404],
#  ['rod', 'curtain', 0.9986888],
#  ['hound', 'fox', 0.9559219],
#  ['street', 'alley', 0.99731463],
#  ['boat', 'deck', 0.98725736],
#  ['car', 'horn', 0.95110446],
#  ['friend', 'guest', 0.96540594],
#  ['employer', 'employee', 0.99943686],
#  ['hand', 'wrist', 0.98858994],
#  ['ball', 'cannon', 0.9972752],
#  ['alcohol', 'brandy', 0.9991865],
#  ['victory', 'triumph', 0.91698223],
#  ['telephone', 'booth', 0.9958373],
#  ['door', 'doorway', 0.9877875],
#  ['motel', 'inn', 0.9940241],
#  ['clothes', 'cloth', 0.9989534],
#  ['steak', 'meat', 0.98872167],
#  ['nail', 'thumb', 0.9980868],
#  ['band', 'orchestra', 0.9916377],
#  ['book', 'bible', 0.9935511],
#  ['business', 'industry', 0.9944669],
#  ['winter', 'season', 0.97309077],
#  ['decade', 'century', 0.99388146],
#  ['alcohol', 'gin', 0.99777097],
#  ['hat', 'coat', 0.8722108],
#  ['window', 'door', 0.9823],
#  ['arm', 'wrist', 0.9965757],
#  ['house', 'apartment', 0.9605775],
#  ['glass', 'crystal', 0.8998867],
#  ['wine', 'brandy', 0.998817],
#  ['creator', 'maker', 0.9969699],
#  ['dinner', 'breakfast', 0.9960886],
#  ['arm', 'muscle', 0.993966],
#  ['bread', 'flour', 0.99959064],
#  ['death', 'tragedy', 0.98759305],
#  ['absence', 'presence', 0.993005],
#  ['gun', 'cannon', 0.9928495],
#  ['grass', 'blade', 0.8077477],
#  ['ball', 'basket', 0.9890219],
#  ['hose', 'garden', 0.99447745],
#  ['boy', 'kid', 0.9829557],
#  ['church', 'choir', 0.9742401],
#  ['clothes', 'drawer', 0.99187475],
#  ['tower', 'bell', 0.9951238],
#  ['father', 'parent', 0.93906754],
#  ['school', 'grade', 0.8492009],
#  ['parent', 'adult', 0.99731207],
#  ['bar', 'jail', 0.98738724],
#  ['car', 'highway', 0.9808544],
#  ['dictionary', 'definition', 0.9994142],
#  ['door', 'cellar', 0.99950427],
#  ['army', 'legion', 0.99128187],
#  ['metal', 'aluminum', 0.9754259],
#  ['chair', 'bench', 0.8771504],
#  ['cloud', 'fog', 0.99775684],
#  ['boy', 'son', 0.9893033],
#  ['water', 'ice', 0.98073596],
#  ['bed', 'blanket', 0.99659663],
#  ['attorney', 'lawyer', 0.9972036],
#  ['area', 'zone', 0.96503496],
#  ['business', 'company', 0.99630713],
#  ['clothes', 'fabric', 0.9962639],
#  ['sweater', 'jacket', 0.97925335],
#  ['money', 'capital', 0.9915275],
#  ['hand', 'foot', 0.918012],
#  ['alcohol', 'cocktail', 0.9948448],
#  ['yard', 'inch', 0.9952017],
#  ['molecule', 'atom', 0.9968043],
#  ['lens', 'camera', 0.9078804],
#  ['meal', 'dinner', 0.99815196],
#  ['eye', 'tear', 0.98756194],
#  ['god', 'devil', 0.96864086],
#  ['loop', 'belt', 0.99936694],
#  ['rat', 'mouse', 0.99858844],
#  ['motor', 'engine', 0.9782605],
#  ['car', 'cab', 0.93707156],
#  ['cat', 'lion', 0.97684526],
#  ['size', 'magnitude', 0.9455673],
#  ['reality', 'fantasy', 0.9985057],
#  ['door', 'gate', 0.99497414],
#  ['cat', 'pet', 0.9500044],
#  ['tin', 'aluminum', 0.99667025],
#  ['bone', 'jaw', 0.99876744],
#  ['cereal', 'wheat', 0.9586913],
#  ['house', 'key', 0.9522544],
#  ['blood', 'flesh', 0.99391496],
#  ['door', 'corridor', 0.9988422],
#  ['god', 'spirit', 0.99114376],
#  ['capability', 'competence', 0.99904335],
#  ['abundance', 'plenty', 0.9896929],
#  ['sofa', 'chair', 0.97592056],
#  ['wall', 'brick', 0.99649996],
#  ['horn', 'drum', 0.9947512],
#  ['organ', 'liver', 0.98104787],
#  ['strength', 'might', 0.98895025],
#  ['phrase', 'word', 0.99978137],
#  ['band', 'parade', 0.95115787],
#  ['stomach', 'waist', 0.997976],
#  ['cloud', 'storm', 0.965651],
#  ['joy', 'pride', 0.9925616],
#  ['noise', 'rattle', 0.9669312],
#  ['rain', 'mist', 0.98859465],
#  ['beer', 'beverage', 0.9915438],
#  ['man', 'uncle', 0.9909104],
#  ['apple', 'juice', 0.9994617],
#  ['intelligence', 'logic', 0.9936744],
#  ['communication', 'language', 0.9892351],
#  ['mink', 'fur', 0.89784324],
#  ['mob', 'crowd', 0.9899364],
#  ['shore', 'coast', 0.9977315],
#  ['wire', 'cord', 0.99971956],
#  ['bird', 'turkey', 0.9753315],
#  ['bed', 'crib', 0.9992896],
#  ['competence', 'ability', 0.9955706],
#  ['cloud', 'haze', 0.9968403],
#  ['supper', 'meal', 0.99161094],
#  ['bar', 'cage', 0.987521],
#  ['water', 'salt', 0.98423415],
#  ['sense', 'intuition', 0.9740635],
#  ['situation', 'condition', 0.9995069],
#  ['crime', 'theft', 0.9822489],
#  ['style', 'fashion', 0.9915803],
#  ['boundary', 'border', 0.99444246],
#  ['arm', 'body', 0.99226844],
#  ['boat', 'car', 0.9340677],
#  ['sandwich', 'lunch', 0.98980236],
#  ['bride', 'princess', 0.9976327],
#  ['heroine', 'hero', 0.99970835],
#  ['car', 'gauge', 0.9880054],
#  ['insect', 'bee', 0.99905455],
#  ['crib', 'cradle', 0.99983346],
#  ['animal', 'person', 0.99849343],
#  ['marijuana', 'herb', 0.99286836],
#  ['bed', 'hospital', 0.9913195],
#  ['cheek', 'tongue', 0.9977985],
#  ['disc', 'computer', 0.9334462],
#  ['curve', 'angle', 0.986435],
#  ['grass', 'moss', 0.86547166],
#  ['school', 'law', 0.99462223],
#  ['foot', 'head', 0.80926687],
#  ['mother', 'guardian', 0.968007],
#  ['orthodontist', 'dentist', 0.9963229],
#  ['alcohol', 'whiskey', 0.99888897],
#  ['mouth', 'tooth', 0.9779496],
#  ['breakfast', 'bacon', 0.9981337],
#  ['bathroom', 'bedroom', 0.9992456],
#  ['plate', 'bowl', 0.9931913],
#  ['meat', 'bacon', 0.99796945],
#  ['air', 'helium', 0.9526756],
#  ['worker', 'employer', 0.9925455],
#  ['body', 'chest', 0.99068254],
#  ['son', 'father', 0.9939407],
#  ['heart', 'surgery', 0.99963266],
#  ['woman', 'secretary', 0.9863544],
#  ['man', 'father', 0.96156675],
#  ['beach', 'island', 0.9968689],
#  ['story', 'topic', 0.9795849],
#  ['game', 'fun', 0.84267837],
#  ['weekend', 'week', 0.95409995],
#  ['couple', 'pair', 0.9926179],
#  ['woman', 'wife', 0.9966113],
#  ['sheep', 'cattle', 0.9955635],
#  ['purse', 'bag', 0.98844945],
#  ['ceiling', 'cathedral', 0.9956021],
#  ['bean', 'coffee', 0.9938047],
#  ['wood', 'paper', 0.9859989],
#  ['top', 'side', 0.99917495],
#  ['crime', 'fraud', 0.9902811],
#  ['pain', 'harm', 0.9986731],
#  ['lover', 'companion', 0.99936557],
#  ['evening', 'dusk', 0.9906044],
#  ['father', 'daughter', 0.9951919],
#  ['wine', 'liquor', 0.98949975],
#  ['cow', 'goat', 0.99825853],
#  ['belief', 'opinion', 0.9967445],
#  ['reality', 'illusion', 0.99798256],
#  ['pact', 'agreement', 0.99581105],
#  ['wealth', 'poverty', 0.9985539],
#  ['accident', 'emergency', 0.9900377],
#  ['battle', 'conquest', 0.9967769],
#  ['friend', 'teacher', 0.99805677],
#  ['illness', 'infection', 0.9996077],
#  ['game', 'trick', 0.9988662],
#  ['brother', 'son', 0.992054],
#  ['aunt', 'nephew', 0.99883044],
#  ['worker', 'mechanic', 0.9919456],
#  ['doctor', 'orthodontist', 0.95323586],
#  ['oak', 'maple', 0.89600873],
#  ['bee', 'queen', 0.9759553],
#  ['car', 'bicycle', 0.96198326],
#  ['goal', 'quest', 0.90516645],
#  ['august', 'month', 0.87797254],
#  ['army', 'squad', 0.8904792],
#  ['cloud', 'weather', 0.9986945],
#  ['physician', 'doctor', 0.9922602],
#  ['canyon', 'valley', 0.99820405],
#  ['river', 'valley', 0.9995398],
#  ['sun', 'sky', 0.9889622],
#  ['target', 'arrow', 0.9988489],
#  ['chocolate', 'pie', 0.9992328],
#  ['circumstance', 'situation', 0.9965045],
#  ['opinion', 'choice', 0.998223],
#  ['rhythm', 'melody', 0.9978929],
#  ['gut', 'nerve', 0.979013],
#  ['day', 'dawn', 0.9843592],
#  ['cattle', 'beef', 0.9989908],
#  ['doctor', 'professor', 0.9880634],
#  ['arm', 'vein', 0.9997773],
#  ['room', 'bath', 0.9831475],
#  ['corporation', 'business', 0.96783406],
#  ['fun', 'football', 0.9746764],
#  ['hill', 'cliff', 0.99659765],
#  ['bone', 'ankle', 0.999795],
#  ['apple', 'candy', 0.9955753],
#  ['helper', 'maid', 0.99897313],
#  ['leader', 'manager', 0.99569523],
#  ['lemon', 'tea', 0.99606895],
#  ['bee', 'ant', 0.99820036],
#  ['basketball', 'baseball', 0.99524766],
#  ['rice', 'bean', 0.9948823],
#  ['bed', 'furniture', 0.9993029],
#  ['emotion', 'passion', 0.9924768],
#  ['anarchy', 'chaos', 0.99192375],
#  ['crime', 'violation', 0.99432325],
#  ['machine', 'engine', 0.97093356],
#  ['beach', 'sea', 0.99861026],
#  ['alley', 'bowl', 0.95864177],
#  ['jar', 'bottle', 0.9580725],
#  ['strength', 'capability', 0.99905825],
#  ['seed', 'mustard', 0.97501326],
#  ['guitar', 'drum', 0.9995936],
#  ['opinion', 'idea', 0.9906236],
#  ['north', 'west', 0.99908733],
#  ['diet', 'salad', 0.94230866],
#  ['mother', 'wife', 0.9965832],
#  ['dad', 'mother', 0.94630134],
#  ['captain', 'sailor', 0.99779195],
#  ['meter', 'yard', 0.9958556],
#  ['beer', 'champagne', 0.9945669],
#  ['motor', 'boat', 0.9990865],
#  ['card', 'bridge', 0.9890601],
#  ['science', 'psychology', 0.97926116],
#  ['sinner', 'saint', 0.9740869],
#  ['destruction', 'construction', 0.9893089],
#  ['crowd', 'bunch', 0.977728],
#  ['beach', 'reef', 0.99910754],
#  ['man', 'child', 0.9870205],
#  ['bread', 'cheese', 0.9990309],
#  ['champion', 'winner', 0.9200543],
#  ['celebration', 'ceremony', 0.9976281],
#  ['menu', 'order', 0.9267145],
#  ['king', 'princess', 0.9932595],
#  ['wealth', 'prestige', 0.99991417],
#  ['endurance', 'strength', 0.9178689],
#  ['danger', 'threat', 0.99954605],
#  ['god', 'priest', 0.9756267],
#  ['men', 'fraternity', 0.9938728],
#  ['buddy', 'companion', 0.97434556],
#  ['teacher', 'helper', 0.948581],
#  ['body', 'stomach', 0.96317035],
#  ['tongue', 'throat', 0.99068],
#  ['house', 'carpet', 0.6310798],
#  ['intelligence', 'skill', 0.98654616],
#  ['journey', 'conquest', 0.9962212],
#  ['god', 'prey', 0.98113316],
#  ['brother', 'soul', 0.9476527],
#  ['adversary', 'opponent', 0.93884176],
#  ['death', 'catastrophe', 0.9879338],
#  ['monster', 'demon', 0.9983601],
#  ['day', 'morning', 0.9942643],
#  ['man', 'victor', 0.9795728],
#  ['friend', 'guy', 0.94800127],
#  ['song', 'story', 0.9962593],
#  ['ray', 'sunshine', 0.998464],
#  ['guy', 'stud', 0.9951441],
#  ['chicken', 'rice', 0.9988685],
#  ['box', 'elevator', 0.9994255],
#  ['butter', 'potato', 0.9985999],
#  ['apartment', 'furniture', 0.99980545],
#  ['lake', 'swamp', 0.98818785],
#  ['salad', 'vinegar', 0.63000566],
#  ['flower', 'bulb', 0.94836813],
#  ['cloud', 'mist', 0.9990149],
#  ['driver', 'pilot', 0.9955802],
#  ['sugar', 'honey', 0.99875814],
#  ['body', 'shoulder', 0.966989],
#  ['idea', 'image', 0.9910679],
#  ['father', 'brother', 0.998988],
#  ['moon', 'planet', 0.9948206],
#  ['ball', 'costume', 0.9836463],
#  ['rail', 'fence', 0.9971101],
#  ['room', 'bed', 0.99879646],
#  ['flower', 'bush', 0.99947536],
#  ['bone', 'knee', 0.99975455],
#  ['arm', 'knee', 0.9957649],
#  ['bottom', 'side', 0.98908037],
#  ['vessel', 'vein', 0.9987261],
#  ['cat', 'rabbit', 0.9796198],
#  ['meat', 'sandwich', 0.9904819],
#  ['belief', 'concept', 0.9974161],
#  ['intelligence', 'insight', 0.98585546],
#  ['attention', 'interest', 0.9978976],
#  ['attitude', 'confidence', 0.9990606],
#  ['right', 'justice', 0.98876935],
#  ['argument', 'agreement', 0.9981748],
#  ['depth', 'magnitude', 0.9492765],
#  ['medium', 'news', 0.99878526],
#  ['winner', 'candidate', 0.6445106],
#  ['birthday', 'date', 0.97597444],
#  ['fee', 'payment', 0.9308676],
#  ['bible', 'hymn', 0.99610233],
#  ['exit', 'doorway', 0.9722702],
#  ['man', 'sentry', 0.99404705],
#  ['aisle', 'hall', 0.9930722],
#  ['whiskey', 'gin', 0.99956274],
#  ['blood', 'marrow', 0.9536706],
#  ['oil', 'mink', 0.9293956],
#  ['floor', 'deck', 0.9984376],
#  ['roof', 'floor', 0.99789786],
#  ['door', 'floor', 0.9950052],
#  ['shoulder', 'head', 0.90802664],
#  ['wagon', 'carriage', 0.9988334],
#  ['car', 'carriage', 0.9039359],
#  ['elbow', 'ankle', 0.999903],
#  ['wealth', 'fame', 0.9925052],
#  ['sorrow', 'shame', 0.9990917],
#  ['administration', 'management', 0.9993314],
#  ['communication', 'conversation', 0.98404574],
#  ['pollution', 'atmosphere', 0.9974006],
#  ['anatomy', 'biology', 0.9876336],
#  ['college', 'profession', 0.9660318],
#  ['book', 'topic', 0.96395767],
#  ['formula', 'equation', 0.7837204],
#  ['book', 'information', 0.9992527],
#  ['boy', 'partner', 0.9982908],
#  ['sky', 'universe', 0.99975437],
#  ['population', 'people', 0.9789951],
#  ['college', 'class', 0.9338051],
#  ['chief', 'mayor', 0.9566283],
#  ['rabbi', 'minister', 0.95902765],
#  ['meter', 'inch', 0.9826624],
#  ['polyester', 'cotton', 0.8676703],
#  ['lawyer', 'banker', 0.9975282],
#  ['violin', 'instrument', 0.99942905],
#  ['camp', 'cabin', 0.9933348],
#  ['pot', 'appliance', 0.99026],
#  ['linen', 'fabric', 0.99517256],
#  ['whiskey', 'champagne', 0.99373025],
#  ['girl', 'child', 0.9888455],
#  ['cottage', 'cabin', 0.993059],
#  ['bird', 'hen', 0.9991297],
#  ['racket', 'noise', 0.998855],
#  ['sunset', 'evening', 0.9983752],
#  ['adult', 'baby', 0.9979793],
#  ['charcoal', 'coal', 0.99723446],
#  ['body', 'spine', 0.9968195],
#  ['head', 'nail', 0.9154233],
#  ['log', 'timber', 0.9932368],
#  ['spoon', 'cup', 0.8446373],
#  ['body', 'nerve', 0.98976094],
#  ['man', 'husband', 0.9829772],
#  ['bone', 'neck', 0.9987114],
#  ['frustration', 'anger', 0.9995503],
#  ['river', 'sea', 0.998415],
#  ['task', 'job', 0.98763186],
#  ['club', 'society', 0.7297469],
#  ['reflection', 'image', 0.9975327],
#  ['prince', 'king', 0.99637896],
#  ['snow', 'weather', 0.992598],
#  ['people', 'party', 0.9872199],
#  ['boy', 'brother', 0.97869515],
#  ['root', 'grass', 0.7828399],
#  ['brow', 'eye', 0.9981629],
#  ['money', 'pearl', 0.95634514],
#  ['money', 'diamond', 0.9697751],
#  ['vehicle', 'bus', 0.99923843],
#  ['cab', 'bus', 0.9993974],
#  ['house', 'barn', 0.9552803],
#  ['finger', 'palm', 0.9971423],
#  ['car', 'bridge', 0.9492273],
#  ['effort', 'difficulty', 0.99697596],
#  ['fact', 'insight', 0.9891714],
#  ['job', 'management', 0.99596196],
#  ['cancer', 'sickness', 0.9831138],
#  ['word', 'newspaper', 0.9917631],
#  ['composer', 'writer', 0.998808],
#  ['actor', 'singer', 0.9998876],
#  ['shelter', 'hut', 0.9836147],
#  ['bathroom', 'kitchen', 0.9994432],
#  ['cabin', 'hut', 0.99160105],
#  ['door', 'kitchen', 0.99855286],
#  ['value', 'belief', 0.98516315],
#  ['wisdom', 'intelligence', 0.9968527],
#  ['ignorance', 'intelligence', 0.9959284],
#  ['happiness', 'luck', 0.9928604],
#  ['idea', 'scheme', 0.9810604],
#  ['mood', 'emotion', 0.9996041],
#  ['happiness', 'peace', 0.9973715],
#  ['despair', 'misery', 0.9889118],
#  ['logic', 'arithmetic', 0.9849706],
#  ['denial', 'confession', 0.9963985],
#  ['argument', 'criticism', 0.9943324],
#  ['aggression', 'hostility', 0.989624],
#  ['hysteria', 'confusion', 0.99817634],
#  ['chemistry', 'theory', 0.9967492],
#  ['trial', 'verdict', 0.99714106],
#  ['comfort', 'safety', 0.9983487],
#  ['confidence', 'self', 0.9928054],
#  ['vision', 'perception', 0.99787515],
#  ['era', 'decade', 0.7583801],
#  ['biography', 'fiction', 0.853933],
#  ['discussion', 'argument', 0.99885195],
#  ['code', 'symbol', 0.99493945],
#  ['danger', 'disease', 0.99814457],
#  ['accident', 'catastrophe', 0.99384135],
#  ['journey', 'trip', 0.9991401],
#  ['activity', 'movement', 0.9907562],
#  ['gossip', 'news', 0.9988706],
#  ['father', 'god', 0.9859043],
#  ['action', 'course', 0.99196917],
#  ['fever', 'illness', 0.99943525],
#  ['aviation', 'flight', 0.98648524],
#  ['game', 'action', 0.8913021],
#  ['molecule', 'air', 0.96855634],
#  ['home', 'state', 0.7578148],
#  ['word', 'literature', 0.97529024],
#  ['adult', 'guardian', 0.99977535],
#  ['newspaper', 'information', 0.9991465],
#  ['communication', 'television', 0.9980841],
#  ['cousin', 'uncle', 0.9979415],
#  ['author', 'reader', 0.98311317],
#  ['guy', 'partner', 0.9938107],
#  ['area', 'corner', 0.9769234],
#  ['ballad', 'song', 0.99680865],
#  ['wall', 'decoration', 0.99638873],
#  ['word', 'page', 0.9834721],
#  ['nurse', 'scientist', 0.9967965],
#  ['politician', 'president', 0.9902155],
#  ['president', 'mayor', 0.97176933],
#  ['book', 'essay', 0.9709455],
#  ['man', 'warrior', 0.9826242],
#  ['article', 'journal', 0.97425765],
#  ['breakfast', 'supper', 0.98786944],
#  ['crowd', 'parade', 0.99896014],
#  ['aisle', 'hallway', 0.98894924],
#  ['teacher', 'rabbi', 0.9723103],
#  ['hip', 'lip', 0.99208164],
#  ['book', 'article', 0.9739963],
#  ['room', 'cell', 0.99776006],
#  ['box', 'booth', 0.9987883],
#  ['daughter', 'kid', 0.9527708],
#  ['limb', 'leg', 0.9639098],
#  ['liver', 'lung', 0.9982484],
#  ['classroom', 'hallway', 0.9848272],
#  ['mountain', 'ledge', 0.9818507],
#  ['car', 'elevator', 0.9339628],
#  ['bed', 'couch', 0.98684347],
#  ['clothes', 'button', 0.9996163],
#  ['clothes', 'coat', 0.99889725],
#  ['kidney', 'organ', 0.9984991],
#  ['apple', 'sauce', 0.9844271],
#  ['chicken', 'steak', 0.9936341],
#  ['car', 'hose', 0.92147297],
#  ['tobacco', 'cigarette', 0.99963075],
#  ['student', 'professor', 0.99056566],
#  ['baby', 'daughter', 0.9696446],
#  ['pipe', 'cigar', 0.9981434],
#  ['milk', 'juice', 0.99949414],
#  ['box', 'cigar', 0.99718827],
#  ['apartment', 'hotel', 0.9992679],
#  ['cup', 'cone', 0.8865636],
#  ['horse', 'ox', 0.9886837],
#  ['throat', 'nose', 0.996424],
#  ['bone', 'teeth', 0.9958777],
#  ['bone', 'elbow', 0.9995378],
#  ['bacon', 'bean', 0.99242604],
#  ['cup', 'jar', 0.9270775],
#  ['proof', 'fact', 0.99536216],
#  ['appointment', 'engagement', 0.98879904],
#  ['birthday', 'year', 0.98200375],
#  ['word', 'clue', 0.97038543],
#  ['author', 'creator', 0.9824897],
#  ['atom', 'carbon', 0.9981141],
#  ['archbishop', 'bishop', 0.9949441],
#  ['letter', 'paragraph', 0.93662715],
#  ['page', 'paragraph', 0.9829884],
#  ['steeple', 'chapel', 0.98791754],
#  ['muscle', 'bone', 0.99971455],
#  ['muscle', 'tongue', 0.9940656],
#  ['boy', 'soldier', 0.99897754],
#  ['belly', 'abdomen', 0.9926509],
#  ['guy', 'girl', 0.9938091],
#  ['bed', 'chair', 0.95924246],
#  ['clothes', 'jacket', 0.9913086],
#  ['gun', 'knife', 0.98353606],
#  ['tin', 'metal', 0.9889844],
#  ['bottle', 'container', 0.98101825],
#  ['hen', 'turkey', 0.98003316],
#  ['meat', 'bread', 0.9985855],
#  ['arm', 'bone', 0.9953198],
#  ['neck', 'spine', 0.99578726],
#  ['apple', 'lemon', 0.9984446],
#  ['agony', 'grief', 0.9987337],
#  ['assignment', 'task', 0.9780749],
#  ['night', 'dawn', 0.99088967],
#  ['dinner', 'soup', 0.99686694],
#  ['calf', 'bull', 0.9994711],
#  ['snow', 'storm', 0.9846421],
#  ['nail', 'hand', 0.98297876],
#  ['dog', 'horse', 0.9996316],
#  ['arm', 'neck', 0.99890685],
#  ['ball', 'glove', 0.9948071],
#  ['flu', 'fever', 0.99149656],
#  ['fee', 'salary', 0.983619],
#  ['nerve', 'brain', 0.99820125],
#  ['beast', 'animal', 0.99188334],
#  ['dinner', 'chicken', 0.99950254],
#  ['girl', 'maid', 0.9968327],
#  ['child', 'boy', 0.99483514],
#  ['alcohol', 'wine', 0.9994409],
#  ['nose', 'mouth', 0.9954404],
#  ['street', 'car', 0.950047],
#  ['bell', 'door', 0.99572134],
#  ['box', 'hat', 0.8992295],
#  ['belief', 'impression', 0.9907396],
#  ['bias', 'opinion', 0.9987445],
#  ['attention', 'awareness', 0.99377567],
#  ['anger', 'mood', 0.9991391],
#  ['elegance', 'style', 0.99462956],
#  ['beauty', 'age', 0.86512834],
#  ['book', 'theme', 0.9924106],
#  ['friend', 'mother', 0.9989778],
#  ['vitamin', 'iron', 0.9974192],
#  ['car', 'factory', 0.9219459],
#  ['pact', 'condition', 0.9788491],
#  ['chapter', 'choice', 0.9947389],
#  ['arithmetic', 'rhythm', 0.9785262],
#  ['winner', 'presence', 0.72437334],
#  ['belief', 'flower', 0.9905095],
#  ['winner', 'goal', 0.9640038],
#  ['trick', 'size', 0.8499121],
#  ['choice', 'vein', 0.9995674],
#  ['hymn', 'conquest', 0.99170464],
#  ['endurance', 'band', 0.86920965],
#  ['jail', 'choice', 0.9902865],
#  ['condition', 'boy', 0.99805087],
#  ['flower', 'endurance', 0.93762934],
#  ['hole', 'agreement', 0.98910385],
#  ['doctor', 'temper', 0.9666905],
#  ['fraternity', 'door', 0.9952247],
#  ['task', 'woman', 0.98318994],
#  ['fraternity', 'baseball', 0.98227924],
#  ['cent', 'size', 0.73135006],
#  ['presence', 'door', 0.9963272],
#  ['mouse', 'management', 0.957628],
#  ['task', 'highway', 0.97550315],
#  ['liquor', 'century', 0.9802889],
#  ['task', 'straw', 0.998435],
#  ['island', 'task', 0.99559414],
#  ['night', 'chapter', 0.97855175],
#  ['pollution', 'president', 0.93736833],
#  ['gun', 'trick', 0.9250256],
#  ['bath', 'trick', 0.9041966],
#  ['diet', 'apple', 0.9992948],
#  ['cent', 'wife', 0.5226265],
#  ['chapter', 'tail', 0.99732924],
#  ['course', 'stomach', 0.98069555],
#  ['hymn', 'straw', 0.9960777],
#  ['dentist', 'colonel', 0.9921778],
#  ['wife', 'straw', 0.9574327],
#  ['hole', 'wife', 0.90613663],
#  ['pupil', 'president', 0.9789907],
#  ['bath', 'wife', 0.921292],
#  ['people', 'cent', 0.5555911],
#  ['formula', 'log', 0.83113664],
#  ['woman', 'fur', 0.99639785],
#  ['apple', 'sunshine', 0.9997282],
#  ['gun', 'dawn', 0.9976963],
#  ['meal', 'waist', 0.9927904],
#  ['camera', 'president', 0.9350401],
#  ['liquor', 'band', 0.95709646],
#  ['stomach', 'vein', 0.9863734],
#  ['gun', 'fur', 0.9531772],
#  ['couch', 'baseball', 0.99116236],
#  ['worker', 'camera', 0.9860188],
#  ['deck', 'mouse', 0.99398696],
#  ['rice', 'boy', 0.98207927],
#  ['people', 'gun', 0.91985],
#  ['cliff', 'tail', 0.9994692],
#  ['ankle', 'window', 0.99017584],
#  ['princess', 'island', 0.9933518],
#  ['container', 'mouse', 0.97594804],
#  ['wagon', 'container', 0.9915429],
#  ['people', 'balloon', 0.97486037],
#  ['dollar', 'people', 0.8764926],
#  ['bath', 'balloon', 0.9905443],
#  ['stomach', 'bedroom', 0.9937197],
#  ['bicycle', 'bedroom', 0.99664104],
#  ['log', 'bath', 0.998559],
#  ['bowl', 'tail', 0.9669999],
#  ['go', 'come', 0.99889004],
#  ['take', 'steal', 0.89937115],
#  ['listen', 'hear', 0.9997336],
#  ['occur', 'happen', 0.9971168],
#  ['vanish', 'disappear', 0.99107945],
#  ['multiply', 'divide', 0.94558036],
#  ['plead', 'beg', 0.9974135],
#  ['begin', 'originate', 0.99816376],
#  ['protect', 'defend', 0.99973434],
#  ['kill', 'destroy', 0.9996128],
#  ['create', 'make', 0.97604847],
#  ['accept', 'reject', 0.9943603],
#  ['ignore', 'avoid', 0.9981322],
#  ['carry', 'bring', 0.97970515],
#  ['leave', 'enter', 0.9982007],
#  ['choose', 'elect', 0.99838537],
#  ['lose', 'fail', 0.9574054],
#  ['encourage', 'discourage', 0.99617356],
#  ['achieve', 'accomplish', 0.997629],
#  ['make', 'construct', 0.9950297],
#  ['listen', 'obey', 0.9989057],
#  ['inform', 'notify', 0.99908197],
#  ['receive', 'give', 0.99918854],
#  ['borrow', 'beg', 0.9923538],
#  ['take', 'obtain', 0.9967304],
#  ['advise', 'recommend', 0.99659365],
#  ['imitate', 'portray', 0.985814],
#  ['win', 'succeed', 0.7055969],
#  ['think', 'decide', 0.9790937],
#  ['greet', 'meet', 0.9893662],
#  ['agree', 'argue', 0.9972431],
#  ['enjoy', 'entertain', 0.9969326],
#  ['destroy', 'make', 0.9973569],
#  ['save', 'protect', 0.98781776],
#  ['give', 'lend', 0.98772943],
#  ['understand', 'know', 0.9980417],
#  ['take', 'receive', 0.99932885],
#  ['accept', 'acknowledge', 0.9970649],
#  ['decide', 'choose', 0.9973118],
#  ['accept', 'believe', 0.99938786],
#  ['keep', 'possess', 0.99403054],
#  ['succeed', 'fail', 0.9985923],
#  ['spend', 'save', 0.994093],
#  ['leave', 'go', 0.99876565],
#  ['come', 'attend', 0.99368006],
#  ['know', 'believe', 0.9972585],
#  ['gather', 'meet', 0.99988085],
#  ['make', 'earn', 0.9952609],
#  ['forget', 'ignore', 0.99230343],
#  ['multiply', 'add', 0.94863343],
#  ['shrink', 'grow', 0.9901761],
#  ['arrive', 'leave', 0.9972341],
#  ['succeed', 'try', 0.9624802],
#  ['accept', 'deny', 0.9977035],
#  ['arrive', 'come', 0.9949681],
#  ['agree', 'differ', 0.98661613],
#  ['send', 'receive', 0.99907446],
#  ['win', 'dominate', 0.80220205],
#  ['add', 'divide', 0.99917024],
#  ['kill', 'choke', 0.90419835],
#  ['acquire', 'get', 0.98026055],
#  ['participate', 'join', 0.99623084],
#  ['leave', 'remain', 0.9998229],
#  ['go', 'enter', 0.99632776],
#  ['take', 'carry', 0.9645926],
#  ['forget', 'learn', 0.9863407],
#  ['appoint', 'elect', 0.9971825],
#  ['engage', 'marry', 0.99839234],
#  ['ask', 'pray', 0.99763715],
#  ['go', 'send', 0.99895704],
#  ['take', 'deliver', 0.98781073],
#  ['speak', 'hear', 0.99948204],
#  ['analyze', 'evaluate', 0.9849251],
#  ['lose', 'keep', 0.93588394],
#  ['compare', 'analyze', 0.9988413],
#  ['go', 'allow', 0.9968046],
#  ['take', 'possess', 0.98700255],
#  ['learn', 'listen', 0.9965966],
#  ['destroy', 'construct', 0.99952286],
#  ['create', 'build', 0.99076766],
#  ['steal', 'buy', 0.9504412],
#  ['kill', 'hang', 0.9974978],
#  ['forget', 'know', 0.9752718],
#  ['create', 'imagine', 0.98208994],
#  ['do', 'happen', 0.97136056],
#  ['win', 'accomplish', 0.81425875],
#  ['give', 'deny', 0.9992833],
#  ['deserve', 'earn', 0.99411345],
#  ['get', 'put', 0.97943544],
#  ['locate', 'find', 0.98915523],
#  ['appear', 'attend', 0.9917042],
#  ['pretend', 'imagine', 0.9857612],
#  ['satisfy', 'please', 0.9979955],
#  ['cherish', 'keep', 0.90950125],
#  ['argue', 'differ', 0.9952143],
#  ['overcome', 'dominate', 0.98980683],
#  ['behave', 'obey', 0.99714947],
#  ['cooperate', 'participate', 0.99173224],
#  ['achieve', 'try', 0.9863668],
#  ['fail', 'discourage', 0.990085],
#  ['begin', 'quit', 0.999849],
#  ['say', 'participate', 0.9859056],
#  ['come', 'bring', 0.9990034],
#  ['declare', 'announce', 0.9955185],
#  ['take', 'leave', 0.99810684],
#  ['proclaim', 'announce', 0.9781313],
#  ['acquire', 'obtain', 0.9975728],
#  ['conclude', 'decide', 0.9890605],
#  ['please', 'plead', 0.99868715],
#  ['argue', 'prove', 0.9947582],
#  ['ask', 'plead', 0.9949841],
#  ['find', 'disappear', 0.98863935],
#  ['inspect', 'examine', 0.99838644],
#  ['verify', 'justify', 0.98950326],
#  ['assume', 'predict', 0.9996316],
#  ['learn', 'evaluate', 0.97022086],
#  ['argue', 'justify', 0.9973023],
#  ['make', 'become', 0.95200306],
#  ['discover', 'originate', 0.9986244],
#  ['achieve', 'succeed', 0.99338984],
#  ['give', 'put', 0.9948694],
#  ['understand', 'listen', 0.99474657],
#  ['expand', 'grow', 0.9994443],
#  ['borrow', 'sell', 0.99980086],
#  ['keep', 'protect', 0.99836856],
#  ['explain', 'prove', 0.99880147],
#  ['assume', 'pretend', 0.98911667],
#  ['agree', 'please', 0.9971753],
#  ['forgive', 'forget', 0.9921402],
#  ['clarify', 'explain', 0.9981978],
#  ['understand', 'forgive', 0.998009],
#  ['remind', 'forget', 0.9816784],
#  ['get', 'remain', 0.99351853],
#  ['realize', 'discover', 0.9974294],
#  ['require', 'inquire', 0.99555796],
#  ['ignore', 'ask', 0.9984367],
#  ['think', 'inquire', 0.99014777],
#  ['reject', 'avoid', 0.99977547],
#  ['argue', 'persuade', 0.9964194],
#  ['pursue', 'persuade', 0.99769884],
#  ['accept', 'forgive', 0.9996105],
#  ['do', 'quit', 0.9519612],
#  ['investigate', 'examine', 0.99838406],
#  ['discuss', 'explain', 0.9972922],
#  ['owe', 'lend', 0.9861957],
#  ['explore', 'discover', 0.9993978],
#  ['complain', 'argue', 0.99904805],
#  ['withdraw', 'reject', 0.9994312],
#  ['keep', 'borrow', 0.9978857],
#  ['beg', 'ask', 0.9874275],
#  ['arrange', 'organize', 0.9957612],
#  ['reduce', 'shrink', 0.98535955],
#  ['speak', 'acknowledge', 0.9982172],
#  ['give', 'borrow', 0.99778306],
#  ['kill', 'defend', 0.9994556],
#  ['disappear', 'shrink', 0.98239183],
#  ['deliver', 'carry', 0.9936806],
#  ['breathe', 'choke', 0.9556369],
#  ['acknowledge', 'notify', 0.9992554],
#  ['become', 'seem', 0.97025216],
#  ['pretend', 'seem', 0.9949788],
#  ['accomplish', 'become', 0.9195622],
#  ['contemplate', 'think', 0.97966355],
#  ['determine', 'predict', 0.9991677],
#  ['please', 'entertain', 0.9975533],
#  ['remain', 'retain', 0.98260355],
#  ['pretend', 'portray', 0.97365165],
#  ['forget', 'retain', 0.99409986],
#  ['want', 'choose', 0.98682374],
#  ['lose', 'get', 0.89528877],
#  ['try', 'think', 0.93056434],
#  ['become', 'appear', 0.9714634],
#  ['leave', 'ignore', 0.9997179],
#  ['accept', 'recommend', 0.9850519],
#  ['leave', 'wander', 0.95184636],
#  ['keep', 'give', 0.999616],
#  ['give', 'allow', 0.9977705],
#  ['bring', 'send', 0.9999276],
#  ['absorb', 'learn', 0.9865597],
#  ['acquire', 'find', 0.9864732],
#  ['leave', 'appear', 0.9995713],
#  ['create', 'destroy', 0.9834672],
#  ['begin', 'go', 0.9907428],
#  ['get', 'buy', 0.9818714],
#  ['collect', 'save', 0.9782609],
#  ['replace', 'restore', 0.99876183],
#  ['join', 'add', 0.9947499],
#  ['join', 'marry', 0.99691737],
#  ['accept', 'deliver', 0.9905397],
#  ['attach', 'join', 0.99588084],
#  ['put', 'hang', 0.99938184],
#  ['go', 'sell', 0.9981476],
#  ['communicate', 'pray', 0.996272],
#  ['give', 'steal', 0.9230271],
#  ['add', 'build', 0.9943727],
#  ['bring', 'restore', 0.99787945],
#  ['portray', 'decide', 0.9995274],
#  ['organize', 'become', 0.95354956],
#  ['give', 'know', 0.9910272],
#  ['say', 'verify', 0.98278147],
#  ['cooperate', 'join', 0.99774],
#  ['arrange', 'require', 0.9980172],
#  ['borrow', 'want', 0.98363],
#  ['investigate', 'pursue', 0.9904486],
#  ['ignore', 'explore', 0.9978261],
#  ['bring', 'complain', 0.99767846],
#  ['enter', 'owe', 0.99650604],
#  ['portray', 'notify', 0.9926444],
#  ['remind', 'sell', 0.98826164],
#  ['absorb', 'possess', 0.99360156],
#  ['join', 'acquire', 0.9977461],
#  ['send', 'attend', 0.99286735],
#  ['gather', 'attend', 0.99384403],
#  ['absorb', 'withdraw', 0.99807334],
#  ['attend', 'arrive', 0.98755884],
#  ['math', 'male', 0.99854517],
#  ['math', 'man', 0.99840266],
#  ['math', 'boy', 0.9962282],
#  ['math', 'brother', 0.9589825],
#  ['math', 'he', 0.9793103],
#  ['math', 'him', 0.9631909],
#  ['math', 'his', 0.98647577],
#  ['math', 'son', 0.9763472],
#  ['math', 'female', 0.9903319],
#  ['math', 'woman', 0.9871155],
#  ...]

# %%
with open('word_pair_similarity_predictions.csv', 'w', newline='') as completed_file:
    write = csv.writer(completed_file)
    write.writerow(incomplete[0])
    write.writerows(complete)
